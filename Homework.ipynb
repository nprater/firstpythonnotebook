# %%
# %matplotlib inline
import pandas as pd
import utils

# %%
raw_data = utils.get_socrata_data("https://data.dcpcsb.org/resource/gi8f-g6am.json")
chi_charter = pd.DataFrame(raw_data)
# Out:
# Got https://data.dcpcsb.org/resource/gi8f-g6am.json?%24offset=0&%24limit=50000

# %% [markdown]
# # My dataset consists of Chicago charter school data. I hope to use Jupyter to look at this information in a different and, hopefully, glean some new details from it.

# %%
chi_charter.head()
# Out:
#     _1  _10  _11  _12   _2 _2013_pmf_score _2013_pmf_tier   _3   _4   _5  \
# 0  NaN  NaN  NaN  NaN  NaN             NaN       Untiered  NaN    6    0
# 1    0  NaN  NaN  NaN    0            0.43              2    8    2    0
# 2   68  NaN  NaN  NaN   47             NaN       Untiered   57   23   12
# 3   54  NaN  NaN  NaN   70            0.62              2   47   23    7
# 4   55  NaN  NaN  NaN   56             NaN       Untiered   77  NaN  NaN
#
#     ...   street_address street_address_address street_address_city  \
# 0   ...              NaN                    NaN                 NaN
# 1   ...              NaN                    NaN                 NaN
# 2   ...              NaN                    NaN                 NaN
# 3   ...              NaN                    NaN                 NaN
# 4   ...              NaN                    NaN                 NaN
#
#   street_address_state street_address_zip  \
# 0                  NaN                NaN
# ...

# %%
chi_charter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340 entries, 0 to 339
# Data columns (total 32 columns):
# _1                                        149 non-null object
# _10                                       44 non-null object
# _11                                       31 non-null object
# _12                                       24 non-null object
# _2                                        144 non-null object
# _2013_pmf_score                           169 non-null object
# _2013_pmf_tier                            340 non-null object
# _3                                        133 non-null object
# _4                                        115 non-null object
# _5                                        119 non-null object
# _6                                        124 non-null object
# _7                                        101 non-null object
# _8                                        93 non-null object
# ...

# %%
chi_charter.total_number_of_names_on_the_wait_list.value_counts().reset_index()
# Out:
#     index  total_number_of_names_on_the_wait_list
# 0       0                                      32
# 1       1                                      10
# 2      38                                       7
# 3       7                                       6
# 4      12                                       5
# 5       5                                       5
# 6       4                                       5
# 7      33                                       4
# 8       6                                       4
# 9       2                                       4
# 10     42                                       4
# 11      9                                       3
# 12      3                                       3
# 13    308                                       3
# 14     26                                       3
# 15     28                                       3
# 16     11                                       3
# 17     13                                       3
# ...

# %%
chi_charter.total_number_of_names_on_the_wait_list.describe()
# Out:
# count     319
# unique    188
# top         0
# freq       32
# Name: total_number_of_names_on_the_wait_list, dtype: object

# %%
chi_charter.total_number_of_seats_available.plot.bar()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-8-d64c86cb413b> in <module>()
# ----> 1 chi_charter.total_number_of_seats_available.plot.bar()
#
# c:\python27\lib\site-packages\pandas\plotting\_core.pyc in bar(self, **kwds)
#    2479         axes : matplotlib.AxesSubplot or np.array of them
#    2480         """
# -> 2481         return self(kind='bar', **kwds)
#    2482
#    2483     def barh(self, **kwds):
#
# c:\python27\lib\site-packages\pandas\plotting\_core.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2444                            colormap=colormap, table=table, yerr=yerr,
#    2445                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2446                            **kwds)
#    2447     __call__.__doc__ = plot_series.__doc__
#    2448
#
# ...

# %%
chi_charter.name_of_school.sum()
# Out:
# u"Excel Academy PCS \u2013 LEADFriendship PCS \u2013 Armstrong AmosCreative Minds International PCSDC Bilingual PCSDC Prep PCS \u2013 Benning ElementaryAcademy of Hope Adult PCSAppleTree Early Learning PCS \u2013 Columbia HeightsAppleTree Early Learning PCS \u2013 SoutheastAppleTree Early Learning PCS \u2013 Lincoln ParkAppleTree Early Learning PCS \u2013 Oklahoma AveAppleTree Early Learning PCS \u2013 SouthwestBASIS DC PCSBridges PCSBriya PCSCapital City PCS \u2013 High SchoolCapital City PCS \u2013 Lower SchoolCarlos Rosario International PCSCedar Tree Academy PCSCenter City PCS \u2013 BrightwoodCenter City PCS \u2013 Congress HeightsDC Prep PCS \u2013 Benning MiddleDC Prep PCS \u2013 Edgewood ElementaryDemocracy Prep Congress Heights PCSDistrict of Columbia International School (Chinese Language Program)District of Columbia International School (French Language Program)District of Columbia International School (Spanish Language Program)E.L. Haynes PCS \u2013 Elementary SchoolE.L. 
# ...

# %%
chi_charter.total_number_of_names_on_the_wait_list.sum()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-10-9f413441871b> in <module>()
# ----> 1 chi_charter.total_number_of_names_on_the_wait_list.sum()
#
# c:\python27\lib\site-packages\pandas\core\generic.pyc in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    6195                                       skipna=skipna)
#    6196         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 6197                             numeric_only=numeric_only)
#    6198
#    6199     return set_function_name(stat_func, name, cls)
#
# c:\python27\lib\site-packages\pandas\core\series.pyc in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2379                                           'numeric_only.'.format(name))
#    2380             with np.errstate(all='ignore'):
# -> 2381                 return op(delegate, skipna=skipna, **kwds)
#    2382
#    2383         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# ...

# %%
chi_charter["number_of_names"] = pd.to_numeric(chi_charter["total_number_of_names_on_the_wait_list"], errors="coerce")

# %%
chi_charter.number_of_names.sum()
# Out:
# 58213.0

# %%
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-22-e6bc61d9b6d8> in <module>()
# ----> 1 chi_charter.total_number_of_seats_available.sum()
#
# c:\python27\lib\site-packages\pandas\core\generic.pyc in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    6195                                       skipna=skipna)
#    6196         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 6197                             numeric_only=numeric_only)
#    6198
#    6199     return set_function_name(stat_func, name, cls)
#
# c:\python27\lib\site-packages\pandas\core\series.pyc in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2379                                           'numeric_only.'.format(name))
#    2380             with np.errstate(all='ignore'):
# -> 2381                 return op(delegate, skipna=skipna, **kwds)
#    2382
#    2383         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# ...
